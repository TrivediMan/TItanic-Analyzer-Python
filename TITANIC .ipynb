# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
#plt.style.use('fivethirtyeight')
#import warnings
#warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
data = pd.read_csv('titanic.csv')

# %%
print(data)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %%
data
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    object
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    object
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), float64(2), int64(4), object(7)
# memory usage: 92.4+ KB

# %%
data.head(15)
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0          0       3    male  22.0      1      0   7.2500        S   Third
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# 3          1       1  female  35.0      1      0  53.1000        S   First
# 4          0       3    male  35.0      0      0   8.0500        S   Third
# 5          0       3    male   NaN      0      0   8.4583        Q   Third
# 6          0       1    male  54.0      0      0  51.8625        S   First
# 7          0       3    male   2.0      3      1  21.0750        S   Third
# 8          1       3  female  27.0      0      2  11.1333        S   Third
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# 11         1       1  female  58.0      0      0  26.5500        S   First
# 12         0       3    male  20.0      0      0   8.0500        S   Third
# 13         0       3    male  39.0      1      5  31.2750        S   Third
# 14         0       3  female  14.0      0      0   7.8542        S   Third
#
#       who  adult_male deck  embark_town alive  alone
# 0     man        True  NaN  Southampton    no  False
# 1   woman       False    C    Cherbourg   yes  False
# 2   woman       False  NaN  Southampton   yes   True
# 3   woman       False    C  Southampton   yes  False
# 4     man        True  NaN  Southampton    no   True
# 5     man        True  NaN   Queenstown    no   True
# 6     man        True    E  Southampton    no   True
# 7   child       False  NaN  Southampton    no  False
# 8   woman       False  NaN  Southampton   yes  False
# 9   child       False  NaN    Cherbourg   yes  False
# 10  child       False    G  Southampton   yes  False
# 11  woman       False    C  Southampton   yes   True
# 12    man        True  NaN  Southampton    no   True
# 13    man        True  NaN  Southampton    no  False
# 14  child       False  NaN  Southampton    no   True

# %%
data.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
f,ax = plt.subplots(1,2,figsize=(12,6))

data['survived'].value_counts().plot.pie(explode=[0,0.3],autopct='%1.1f%%',ax=ax[0],shadow=True)

ax[0].set_title('survived')
ax[0].set_ylabel('')

sns.countplot(x='survived',data=data,ax=ax[1])
ax[1].set_title('survived')

plt.show()

# %%
data.groupby(['sex','survived'])['survived'].count()
# Out:
# sex     survived
# female  0            81
#         1           233
# male    0           468
#         1           109
# Name: survived, dtype: int64

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

f, ax = plt.subplots(1, 2, figsize=(18, 8))

data[['sex', 'survived']].groupby(['sex']).mean().plot.bar(ax=ax[0])
ax[0].set_title('Survived vs Sex')

sns.countplot(x='sex', hue='survived', data=data, ax=ax[1])
ax[1].set_title('Sex: Survived vs Dead')

plt.show()

# %%
pd.crosstab(data.pclass,data.survived,margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_d60ab_row0_col0, #T_d60ab_row1_col1, #T_d60ab_row1_col2 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_d60ab_row0_col1 {
#   background-color: #cee666;
#   color: #000000;
# }
# #T_d60ab_row0_col2 {
#   background-color: #f4fa66;
#   color: #000000;
# }
# #T_d60ab_row1_col0 {
#   background-color: #f6fa66;
#   color: #000000;
# }
# #T_d60ab_row2_col0 {
#   background-color: #60b066;
#   color: #f1f1f1;
# }
# #T_d60ab_row2_col1 {
#   background-color: #dfef66;
#   color: #000000;
# }
# #T_d60ab_row2_col2 {
#   background-color: #90c866;
#   color: #000000;
# }
# #T_d60ab_row3_col0, #T_d60ab_row3_col1, #T_d60ab_row3_col2 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_d60ab">
#   <thead>
#     <tr>
#       <th class="index_name level0" >survived</th>
#       <th id="T_d60ab_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_d60ab_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_d60ab_level0_col2" class="col_heading level0 col2" >All</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >pclass</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d60ab_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_d60ab_row0_col0" class="data row0 col0" >80</td>
#       <td id="T_d60ab_row0_col1" class="data row0 col1" >136</td>
#       <td id="T_d60ab_row0_col2" class="data row0 col2" >216</td>
#     </tr>
#     <tr>
#       <th id="T_d60ab_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_d60ab_row1_col0" class="data row1 col0" >97</td>
#       <td id="T_d60ab_row1_col1" class="data row1 col1" >87</td>
#       <td id="T_d60ab_row1_col2" class="data row1 col2" >184</td>
#     </tr>
#     <tr>
#       <th id="T_d60ab_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_d60ab_row2_col0" class="data row2 col0" >372</td>
#       <td id="T_d60ab_row2_col1" class="data row2 col1" >119</td>
#       <td id="T_d60ab_row2_col2" class="data row2 col2" >491</td>
#     </tr>
#     <tr>
#       <th id="T_d60ab_level0_row3" class="row_heading level0 row3" >All</th>
#       <td id="T_d60ab_row3_col0" class="data row3 col0" >549</td>
#       <td id="T_d60ab_row3_col1" class="data row3 col1" >342</td>
#       <td id="T_d60ab_row3_col2" class="data row3 col2" >891</td>
#     </tr>
#   </tbody>
# </table>

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))


data['pclass'].value_counts().plot.bar(color=['#CD7F32','#FFDF00','#D3D3D3'],ax=ax[0])

ax[0].set_title('Number Of Passengers By Pclass')

ax[0].set_ylabel('Count')



sns.countplot(x='pclass',hue='survived',data=data,ax=ax[1])

ax[1].set_title('pclass:survived vs Dead')

plt.show()

# %%
pd.crosstab([data.sex,data.survived],data.pclass,margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_372a6_row0_col0, #T_372a6_row0_col1, #T_372a6_row0_col3, #T_372a6_row3_col2 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_372a6_row0_col2, #T_372a6_row1_col2 {
#   background-color: #f1f866;
#   color: #000000;
# }
# #T_372a6_row1_col0 {
#   background-color: #96cb66;
#   color: #000000;
# }
# #T_372a6_row1_col1 {
#   background-color: #a3d166;
#   color: #000000;
# }
# #T_372a6_row1_col3 {
#   background-color: #cfe766;
#   color: #000000;
# }
# #T_372a6_row2_col0 {
#   background-color: #a7d366;
#   color: #000000;
# }
# #T_372a6_row2_col1, #T_372a6_row2_col3 {
#   background-color: #85c266;
#   color: #000000;
# }
# #T_372a6_row2_col2 {
#   background-color: #6eb666;
#   color: #f1f1f1;
# }
# #T_372a6_row3_col0 {
#   background-color: #cde666;
#   color: #000000;
# }
# #T_372a6_row3_col1 {
#   background-color: #f0f866;
#   color: #000000;
# }
# #T_372a6_row3_col3 {
#   background-color: #f7fb66;
#   color: #000000;
# }
# #T_372a6_row4_col0, #T_372a6_row4_col1, #T_372a6_row4_col2, #T_372a6_row4_col3 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_372a6">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >pclass</th>
#       <th id="T_372a6_level0_col0" class="col_heading level0 col0" >1</th>
#       <th id="T_372a6_level0_col1" class="col_heading level0 col1" >2</th>
#       <th id="T_372a6_level0_col2" class="col_heading level0 col2" >3</th>
#       <th id="T_372a6_level0_col3" class="col_heading level0 col3" >All</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >sex</th>
#       <th class="index_name level1" >survived</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_372a6_level0_row0" class="row_heading level0 row0" rowspan="2">female</th>
#       <th id="T_372a6_level1_row0" class="row_heading level1 row0" >0</th>
#       <td id="T_372a6_row0_col0" class="data row0 col0" >3</td>
#       <td id="T_372a6_row0_col1" class="data row0 col1" >6</td>
#       <td id="T_372a6_row0_col2" class="data row0 col2" >72</td>
#       <td id="T_372a6_row0_col3" class="data row0 col3" >81</td>
#     </tr>
#     <tr>
#       <th id="T_372a6_level1_row1" class="row_heading level1 row1" >1</th>
#       <td id="T_372a6_row1_col0" class="data row1 col0" >91</td>
#       <td id="T_372a6_row1_col1" class="data row1 col1" >70</td>
#       <td id="T_372a6_row1_col2" class="data row1 col2" >72</td>
#       <td id="T_372a6_row1_col3" class="data row1 col3" >233</td>
#     </tr>
#     <tr>
#       <th id="T_372a6_level0_row2" class="row_heading level0 row2" rowspan="2">male</th>
#       <th id="T_372a6_level1_row2" class="row_heading level1 row2" >0</th>
#       <td id="T_372a6_row2_col0" class="data row2 col0" >77</td>
#       <td id="T_372a6_row2_col1" class="data row2 col1" >91</td>
#       <td id="T_372a6_row2_col2" class="data row2 col2" >300</td>
#       <td id="T_372a6_row2_col3" class="data row2 col3" >468</td>
#     </tr>
#     <tr>
#       <th id="T_372a6_level1_row3" class="row_heading level1 row3" >1</th>
#       <td id="T_372a6_row3_col0" class="data row3 col0" >45</td>
#       <td id="T_372a6_row3_col1" class="data row3 col1" >17</td>
#       <td id="T_372a6_row3_col2" class="data row3 col2" >47</td>
#       <td id="T_372a6_row3_col3" class="data row3 col3" >109</td>
#     </tr>
#     <tr>
#       <th id="T_372a6_level0_row4" class="row_heading level0 row4" >All</th>
#       <th id="T_372a6_level1_row4" class="row_heading level1 row4" ></th>
#       <td id="T_372a6_row4_col0" class="data row4 col0" >216</td>
#       <td id="T_372a6_row4_col1" class="data row4 col1" >184</td>
#       <td id="T_372a6_row4_col2" class="data row4 col2" >491</td>
#       <td id="T_372a6_row4_col3" class="data row4 col3" >891</td>
#     </tr>
#   </tbody>
# </table>

# %%
sns.catplot(x='pclass',y='survived',hue='sex',data=data, kind='bar')
plt.show()

# %%
print('Oldest Passenger was of:',data['age'].max(),'years')
print('Youngest Passenger was of:',data['age'].min(),'years')
print('Average Age on the ship:',data['age'].mean(),'years')
# Out:
# Oldest Passenger was of: 80.0 years
# Youngest Passenger was of: 0.42 years
# Average Age on the ship: 29.69911764705882 years

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

pd.read_csv('titanic.csv')

f,ax = plt.subplots(1,2,figsize=(18,8))

data['age'].value_counts().plot.bar(color=['#CD7F32','#FFDF00','#D3D3D3'],ax=ax[0])

ax[0].set_title('Number Of Passengers By age')

ax[0].set_ylabel('Count')

sns.countplot(x='age',hue='survived',data=data.head(10),ax=ax[1])

ax[1].set_title('age:survived vs Dead')

plt.show()

# %%
pd.crosstab([data.embarked,data.pclass],[data.sex,data.survived],margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_687ea_row0_col0, #T_687ea_row1_col2 {
#   background-color: #fcfe66;
#   color: #000000;
# }
# #T_687ea_row0_col1 {
#   background-color: #d2e866;
#   color: #000000;
# }
# #T_687ea_row0_col2 {
#   background-color: #f2f866;
#   color: #000000;
# }
# #T_687ea_row0_col3 {
#   background-color: #d8ec66;
#   color: #000000;
# }
# #T_687ea_row0_col4, #T_687ea_row2_col3 {
#   background-color: #e8f466;
#   color: #000000;
# }
# #T_687ea_row1_col0, #T_687ea_row3_col0, #T_687ea_row3_col1, #T_687ea_row3_col2, #T_687ea_row3_col3, #T_687ea_row3_col4, #T_687ea_row4_col0, #T_687ea_row4_col2, #T_687ea_row4_col3, #T_687ea_row4_col4 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_687ea_row1_col1, #T_687ea_row6_col0 {
#   background-color: #f9fc66;
#   color: #000000;
# }
# #T_687ea_row1_col3, #T_687ea_row1_col4 {
#   background-color: #fbfd66;
#   color: #000000;
# }
# #T_687ea_row2_col0, #T_687ea_row5_col1 {
#   background-color: #e6f266;
#   color: #000000;
# }
# #T_687ea_row2_col1 {
#   background-color: #f0f866;
#   color: #000000;
# }
# #T_687ea_row2_col2 {
#   background-color: #eef666;
#   color: #000000;
# }
# #T_687ea_row2_col4, #T_687ea_row7_col0 {
#   background-color: #edf666;
#   color: #000000;
# }
# #T_687ea_row4_col1 {
#   background-color: #fefe66;
#   color: #000000;
# }
# #T_687ea_row5_col0 {
#   background-color: #e3f166;
#   color: #000000;
# }
# #T_687ea_row5_col2 {
#   background-color: #ecf666;
#   color: #000000;
# }
# #T_687ea_row5_col3 {
#   background-color: #f8fc66;
#   color: #000000;
# }
# #T_687ea_row5_col4 {
#   background-color: #ebf566;
#   color: #000000;
# }
# #T_687ea_row6_col1 {
#   background-color: #cde666;
#   color: #000000;
# }
# #T_687ea_row6_col2 {
#   background-color: #e4f266;
#   color: #000000;
# }
# #T_687ea_row6_col3 {
#   background-color: #bede66;
#   color: #000000;
# }
# #T_687ea_row6_col4 {
#   background-color: #dbed66;
#   color: #000000;
# }
# #T_687ea_row7_col1 {
#   background-color: #bdde66;
#   color: #000000;
# }
# #T_687ea_row7_col2 {
#   background-color: #d3e966;
#   color: #000000;
# }
# #T_687ea_row7_col3, #T_687ea_row8_col1 {
#   background-color: #dcee66;
#   color: #000000;
# }
# #T_687ea_row7_col4 {
#   background-color: #d1e866;
#   color: #000000;
# }
# #T_687ea_row8_col0 {
#   background-color: #52a866;
#   color: #f1f1f1;
# }
# #T_687ea_row8_col2 {
#   background-color: #81c066;
#   color: #000000;
# }
# #T_687ea_row8_col3 {
#   background-color: #b0d866;
#   color: #000000;
# }
# #T_687ea_row8_col4 {
#   background-color: #9acc66;
#   color: #000000;
# }
# #T_687ea_row9_col0, #T_687ea_row9_col1, #T_687ea_row9_col2, #T_687ea_row9_col3, #T_687ea_row9_col4 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_687ea">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >sex</th>
#       <th id="T_687ea_level0_col0" class="col_heading level0 col0" colspan="2">female</th>
#       <th id="T_687ea_level0_col2" class="col_heading level0 col2" colspan="2">male</th>
#       <th id="T_687ea_level0_col4" class="col_heading level0 col4" >All</th>
#     </tr>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level1" >survived</th>
#       <th id="T_687ea_level1_col0" class="col_heading level1 col0" >0</th>
#       <th id="T_687ea_level1_col1" class="col_heading level1 col1" >1</th>
#       <th id="T_687ea_level1_col2" class="col_heading level1 col2" >0</th>
#       <th id="T_687ea_level1_col3" class="col_heading level1 col3" >1</th>
#       <th id="T_687ea_level1_col4" class="col_heading level1 col4" ></th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >embarked</th>
#       <th class="index_name level1" >pclass</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_687ea_level0_row0" class="row_heading level0 row0" rowspan="3">C</th>
#       <th id="T_687ea_level1_row0" class="row_heading level1 row0" >1</th>
#       <td id="T_687ea_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_687ea_row0_col1" class="data row0 col1" >42</td>
#       <td id="T_687ea_row0_col2" class="data row0 col2" >25</td>
#       <td id="T_687ea_row0_col3" class="data row0 col3" >17</td>
#       <td id="T_687ea_row0_col4" class="data row0 col4" >85</td>
#     </tr>
#     <tr>
#       <th id="T_687ea_level1_row1" class="row_heading level1 row1" >2</th>
#       <td id="T_687ea_row1_col0" class="data row1 col0" >0</td>
#       <td id="T_687ea_row1_col1" class="data row1 col1" >7</td>
#       <td id="T_687ea_row1_col2" class="data row1 col2" >8</td>
#       <td id="T_687ea_row1_col3" class="data row1 col3" >2</td>
#       <td id="T_687ea_row1_col4" class="data row1 col4" >17</td>
#     </tr>
#     <tr>
#       <th id="T_687ea_level1_row2" class="row_heading level1 row2" >3</th>
#       <td id="T_687ea_row2_col0" class="data row2 col0" >8</td>
#       <td id="T_687ea_row2_col1" class="data row2 col1" >15</td>
#       <td id="T_687ea_row2_col2" class="data row2 col2" >33</td>
#       <td id="T_687ea_row2_col3" class="data row2 col3" >10</td>
#       <td id="T_687ea_row2_col4" class="data row2 col4" >66</td>
#     </tr>
#     <tr>
#       <th id="T_687ea_level0_row3" class="row_heading level0 row3" rowspan="3">Q</th>
#       <th id="T_687ea_level1_row3" class="row_heading level1 row3" >1</th>
#       <td id="T_687ea_row3_col0" class="data row3 col0" >0</td>
#       <td id="T_687ea_row3_col1" class="data row3 col1" >1</td>
#       <td id="T_687ea_row3_col2" class="data row3 col2" >1</td>
#       <td id="T_687ea_row3_col3" class="data row3 col3" >0</td>
#       <td id="T_687ea_row3_col4" class="data row3 col4" >2</td>
#     </tr>
#     <tr>
#       <th id="T_687ea_level1_row4" class="row_heading level1 row4" >2</th>
#       <td id="T_687ea_row4_col0" class="data row4 col0" >0</td>
#       <td id="T_687ea_row4_col1" class="data row4 col1" >2</td>
#       <td id="T_687ea_row4_col2" class="data row4 col2" >1</td>
#       <td id="T_687ea_row4_col3" class="data row4 col3" >0</td>
#       <td id="T_687ea_row4_col4" class="data row4 col4" >3</td>
#     </tr>
#     <tr>
#       <th id="T_687ea_level1_row5" class="row_heading level1 row5" >3</th>
#       <td id="T_687ea_row5_col0" class="data row5 col0" >9</td>
#       <td id="T_687ea_row5_col1" class="data row5 col1" >24</td>
#       <td id="T_687ea_row5_col2" class="data row5 col2" >36</td>
#       <td id="T_687ea_row5_col3" class="data row5 col3" >3</td>
#       <td id="T_687ea_row5_col4" class="data row5 col4" >72</td>
#     </tr>
#     <tr>
#       <th id="T_687ea_level0_row6" class="row_heading level0 row6" rowspan="3">S</th>
#       <th id="T_687ea_level1_row6" class="row_heading level1 row6" >1</th>
#       <td id="T_687ea_row6_col0" class="data row6 col0" >2</td>
#       <td id="T_687ea_row6_col1" class="data row6 col1" >46</td>
#       <td id="T_687ea_row6_col2" class="data row6 col2" >51</td>
#       <td id="T_687ea_row6_col3" class="data row6 col3" >28</td>
#       <td id="T_687ea_row6_col4" class="data row6 col4" >127</td>
#     </tr>
#     <tr>
#       <th id="T_687ea_level1_row7" class="row_heading level1 row7" >2</th>
#       <td id="T_687ea_row7_col0" class="data row7 col0" >6</td>
#       <td id="T_687ea_row7_col1" class="data row7 col1" >61</td>
#       <td id="T_687ea_row7_col2" class="data row7 col2" >82</td>
#       <td id="T_687ea_row7_col3" class="data row7 col3" >15</td>
#       <td id="T_687ea_row7_col4" class="data row7 col4" >164</td>
#     </tr>
#     <tr>
#       <th id="T_687ea_level1_row8" class="row_heading level1 row8" >3</th>
#       <td id="T_687ea_row8_col0" class="data row8 col0" >55</td>
#       <td id="T_687ea_row8_col1" class="data row8 col1" >33</td>
#       <td id="T_687ea_row8_col2" class="data row8 col2" >231</td>
#       <td id="T_687ea_row8_col3" class="data row8 col3" >34</td>
#       <td id="T_687ea_row8_col4" class="data row8 col4" >353</td>
#     </tr>
#     <tr>
#       <th id="T_687ea_level0_row9" class="row_heading level0 row9" >All</th>
#       <th id="T_687ea_level1_row9" class="row_heading level1 row9" ></th>
#       <td id="T_687ea_row9_col0" class="data row9 col0" >81</td>
#       <t

# %%
sns.catplot(x='embarked',y='survived',data=data,kind='bar')
fig=plt.gcf()
fig.set_size_inches(5,3)
plt.show()

# %%
f,ax=plt.subplots(2,2,figsize=(20,15))

sns.plot(x='embarked',data=data,ax=ax[0,0])
ax[0,0].set_title('No. Of Passengers Boarded')

sns.countplot(x='embarked',hue='sex',data=data,ax=ax[0,1])
ax[0,1].set_title('Male-Female Split for Embarked')

sns.countplot(x='embarked',hue='survived',data=data,ax=ax[1,0])
ax[1,0].set_title('Embarked vs Survived')

sns.countplot(x='embarked',hue='pclass',data=data,ax=ax[1,1])
ax[1,1].set_title('Embarked vs Pclass')

plt.subplots_adjust(wspace=0.2,hspace=0.5)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[25], line 3
#       1 f,ax=plt.subplots(2,2,figsize=(20,15))
# ----> 3 sns.subplot(x='embarked',data=data,ax=ax[0,0])
#       4 ax[0,0].set_title('No. Of Passengers Boarded')
#       6 sns.countplot(x='embarked',hue='sex',data=data,ax=ax[0,1])
#
# AttributeError: module 'seaborn' has no attribute 'subplot'

# %%
sns.catplot(x='pclass',y='survived',hue='sex',col='embarked',data=data)
plt.show()

# %%
data['embarked'].fillna('S',inplace = True)
# Out:
# C:\Users\mantr\AppData\Local\Temp\ipykernel_20204\268653635.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['embarked'].fillna('S',inplace = True)

# %%
data.embarked.isnull().any()
# Out:
# np.False_

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

data = pd.read_csv('titanic.csv')

data['Age_band']=0

data.loc[data['age']<=16,'Age_band']=0

data.loc[(data['age']>16)&(data['age']<=32),'Age_band']=1

data.loc[(data['age']>32)&(data['age']<=48),'Age_band']=2

data.loc[(data['age']>48)&(data['age']<=64),'Age_band']=3

data.loc[data['age']>64,'Age_band']=4

data.head(10)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0         0       3    male  22.0      1      0   7.2500        S   Third
# 1         1       1  female  38.0      1      0  71.2833        C   First
# 2         1       3  female  26.0      0      0   7.9250        S   Third
# 3         1       1  female  35.0      1      0  53.1000        S   First
# 4         0       3    male  35.0      0      0   8.0500        S   Third
# 5         0       3    male   NaN      0      0   8.4583        Q   Third
# 6         0       1    male  54.0      0      0  51.8625        S   First
# 7         0       3    male   2.0      3      1  21.0750        S   Third
# 8         1       3  female  27.0      0      2  11.1333        S   Third
# 9         1       2  female  14.0      1      0  30.0708        C  Second
#
#      who  adult_male deck  embark_town alive  alone  Age_band
# 0    man        True  NaN  Southampton    no  False         1
# 1  woman       False    C    Cherbourg   yes  False         2
# 2  woman       False  NaN  Southampton   yes   True         1
# 3  woman       False    C  Southampton   yes  False         2
# 4    man        True  NaN  Southampton    no   True         2
# 5    man        True  NaN   Queenstown    no   True         0
# 6    man        True    E  Southampton    no   True         3
# 7  child       False  NaN  Southampton    no  False         0
# 8  woman       False  NaN  Southampton   yes  False         1
# 9  child       False  NaN    Cherbourg   yes  False         0

# %%
data['Age_band'].value_counts().to_frame().style.background_gradient(cmap='summer')
# Out:
# <style type="text/css">
# #T_3e6ef_row0_col0 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_3e6ef_row1_col0 {
#   background-color: #cbe566;
#   color: #000000;
# }
# #T_3e6ef_row2_col0 {
#   background-color: #87c366;
#   color: #000000;
# }
# #T_3e6ef_row3_col0 {
#   background-color: #2c9666;
#   color: #f1f1f1;
# }
# #T_3e6ef_row4_col0 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_3e6ef">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3e6ef_level0_col0" class="col_heading level0 col0" >count</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Age_band</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3e6ef_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_3e6ef_row0_col0" class="data row0 col0" >346</td>
#     </tr>
#     <tr>
#       <th id="T_3e6ef_level0_row1" class="row_heading level0 row1" >0</th>
#       <td id="T_3e6ef_row1_col0" class="data row1 col0" >277</td>
#     </tr>
#     <tr>
#       <th id="T_3e6ef_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_3e6ef_row2_col0" class="data row2 col0" >188</td>
#     </tr>
#     <tr>
#       <th id="T_3e6ef_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_3e6ef_row3_col0" class="data row3 col0" >69</td>
#     </tr>
#     <tr>
#       <th id="T_3e6ef_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_3e6ef_row4_col0" class="data row4 col0" >11</td>
#     </tr>
#   </tbody>
# </table>
